# %% [markdown]
# IMPORTAMOS LAS LIBRERÍAS

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import warnings
import re
warnings.filterwarnings("ignore")

# %% [markdown]
# VAMOS A SCRAPPEAR LA PÁGINA WEB DE UBER EATS

# %% [markdown]
# OPCIONES DE SELENIUM PARA EVITAR QUE SEPAN QUE ERES UN BOT

# %%
#Opciones de Selenium para evitar que sepan que eres un robot
opciones= Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
#para ocultarme como robot, pero me sigue diciendo que hay un software automatico usando chrome
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--start-maximized') #empezar maximizado
opciones.add_argument('user.data-dir=selenium') #guarda las cookies
opciones.add_argument('drive/adblock.crx') #adblocker
#opciones.add_argument('--incognito')#incognito window

# %%
# AQUI INTENTO SACAR TODO Y APENDEARLO EN LISTAS DE CATEGORÍAS, EL MÁS CAÓTICO!


driver = webdriver.Chrome(ChromeDriverManager().install())
restaurantes = []
likes = []
precio = []
eta = []
   
#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(2)
print("Url - Okey")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(2)
print("Cookies - Okey")
    
#LE DAMOS UNA DIRECCIÓN DE ENTREGA, HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(2)
print("Click dirección - Okey")

#TENEMOS QUE ESCRIBIR LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Lopez de Hoyos, 13, Madrid")
driver.implicitly_wait(2)
print("Dirección - Okey")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(2)
print("Confirmamos dirección - Okey")

#LE DAMOS UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(2)
print("Click categoría - Okey")

#TENEMOS QUE ESCRIBIR LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(2)
print("Categoría - Okey")
print("Estamos cerca!! ")

#SACAMOS LA DATA DE CADA TABLA
for number in range (1,27):
    restaurantes.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/a/h3').text)
    likes.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/span').text)
    precio.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[2]').text)
    eta.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[3]/span/div').text)
    driver.implicitly_wait(2)
print("Congratulations, tenemos la data que necesitamos de la primera pagina!")

driver.quit
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/juanvegapenichet/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# Url - Okey
# Cookies - Okey
# Click dirección - Okey
# Dirección - Okey
# Confirmamos dirección - Okey
# Click categoría - Okey
# Categoría - Okey
# Estamos cerca!!
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_86322/1410151185.py in <module>
#      50     likes.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/span').text)
#      51     precio.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[2]').text)
# ---> 52     eta.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[3]/span/div').text)
#      53     driver.implicitly_wait(2)
#      54 print("Congratulations, tenemos la data que necesitamos de la primera pagina!")
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     512             stacklevel=2,
#     513         )
# --> 514         return self.find_element(by=By.XPATH, value=xpath)
#     515
#     516     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1236             value = '[name="%s"]' % value
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#    1240             'value': value})['value']
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[2]/div/div/div/div[2]/div[2]/div[3]/span/div"}
#   (Session info: chrome=96.0.4664.55)
# Stacktrace:
# 0   chromedriver                        0x0000000104586269 __gxx_personality_v0 + 582729
# 1   chromedriver                        0x0000000104511c33 __gxx_personality_v0 + 106003
# 2   chromedriver                        0x00000001040cee28 chromedriver + 171560
# 3   chromedriver                        0x00000001041043d2 chromedriver + 390098
# 4   chromedriver                        0x0000000104104591 chromedriver + 390545
# 5   chromedriver                        0x00000001041366b4 chromedriver + 595636
# 6   chromedriver                        0x00000001041219fd chromedriver + 510461
# 7   chromedriver                        0x0000000104134462 chromedriver + 586850
# 8   chromedriver                        0x0000000104121c23 chromedriver + 511011
# 9   chromedriver                        0x00000001040f775e chromedriver + 337758
# 10  chromedriver                        0x00000001040f8a95 chromedriver + 342677
# 11  chromedriver                        0x00000001045428ab __gxx_personality_v0 + 305803
# 12  chromedriver                        0x0000000104559863 __gxx_personality_v0 + 399939
# 13  chromedriver                        0x000000010455ec7f __gxx_personality_v0 + 421471
# 14  chromedriver                        0x000000010455abba __gxx_personality_v0 + 404890
# 15  chromedriver                        0x0000000104536e51 __gxx_personality_v0 + 258097
# 16  chromedriver                        0x0000000104576158 __gxx_personality_v0 + 516920
# 17  chromedriver                        0x00000001045762e1 __gxx_personality_v0 + 517313
# 18  chromedriver                        0x000000010458d6f8 __gxx_personality_v0 + 612568
# 19  libsystem_pthread.dylib             0x00007fff2036d8fc _pthread_start + 224
# 20  libsystem_pthread.dylib             0x00007fff20369443 thread_start + 15

# %%
print(restaurantes)
# Out:
# ['La Tagliatella - Madrid Juan Bravo', 'TUTTO PASTA!']

# %%
print(likes)
# Out:
# ['Uno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 35 opiniones.', 'Valorado con 2.9 de 5 estrellas según 28 opiniones.']

# %%
print(precio)
# Out:
# ['Los gastos de envío son de 1.40€.\nPrecio de 1.40€', '40–60 min']

# %%
print(eta)
# Out:
# ['35–45 min']

# %%
# AQUI INTENTO SACAR TODO Y APENDEARLO EN UN DICCIONARIO, DE FORMA ORDENADA!!!
# ESPERO QUE SALGA ASÍ :)


driver = webdriver.Chrome(ChromeDriverManager().install())
dicc = {"Restaurantes": [],
        "Valorado": [],
        "Nota": [],
        "Gastos": [],
        "Delivery fee": [],
        "ETA": [],
        "Mierda1": [],
        "Mierda2": [],
        "Mierda3": []}
   
#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(2)
print("Url - Okey")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(2)
print("Cookies - Okey")
    
#LE DAMOS UNA DIRECCIÓN DE ENTREGA, HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(2)
print("Click dirección - Okey")

#TENEMOS QUE ESCRIBIR LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Lopez de Hoyos, 13, Madrid")
driver.implicitly_wait(2)
print("Dirección - Okey")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(2)
print("Confirmamos dirección - Okey")

#LE DAMOS UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(2)
print("Click categoría - Okey")

#TENEMOS QUE ESCRIBIR LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(2)
print("Categoría - Okey")
print("Estamos cerca!! ")

#SACAMOS LA DATA DE CADA TABLA
for number in range (1,80):
    try:
        dicc["Restaurantes"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/div[1]').text)
    except:
        dicc["Restaurantes"].append(driver.find_element_by_xpath(f'//*[@id="main-content"]/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/div[1]').text)
    try:
        dicc["Valorado"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.mg.dh.ah.b6.bf > span').text)
    except:
        dicc["Valorado"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/span').text)
    try:
        dicc["Nota"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.mg.dh.ah.b6.bf > div.ba.mh.bb.bu.fn.fm.mi.c6.he.ah.bf.bg').text)
    except:
        dicc["Nota"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/div[3]').text)
    try:
        dicc["Gastos"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]').text)
    except:
        dicc["Gastos"].append(driver.find_element_by_xpath(f'//*[@id="main-content"]/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]').text)
    try:
        dicc["Delivery_fee"].append(driver.find_element_by_xpath(f'//*[@id="main-content"]/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]/span[1]').text)
    except:
        dicc["Delivery_fee"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]/span[1]').text)
    try:
        dicc["ETA"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.dh.eu.ah.bf.en > div.ch.cf.hg').text)
    except:
        dicc["ETA"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.dh.eu.ah.bf.en > div.ch.cf.hg > span > div').text)
    try:
        dicc["Mierda1"].append(driver.find_element_by_xpath(f'').text)
    except:
        dicc["Mierda1"].append
    try:
        dicc["Mierda2"].append(driver.find_element_by_xpath(f'').text)
    except:
        dicc["Mierda2"].append
    try:
        dicc["Mierda3"].append(driver.find_element_by_xpath(f'').text)
    except:
        dicc["Mierda3"].append

        driver.implicitly_wait(2)
        
print("Congratulations, tenemos la data que necesitamos de la primera pagina!")

driver.quit
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/juanvegapenichet/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# Url - Okey
# Cookies - Okey
# Click dirección - Okey
# Dirección - Okey
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_86322/2562939030.py in <module>
#      27
#      28 #CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
# ---> 29 driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
#      30 driver.implicitly_wait(2)
#      31 print("Confirmamos dirección - Okey")
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     512             stacklevel=2,
#     513         )
# --> 514         return self.find_element(by=By.XPATH, value=xpath)
#     515
#     516     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1236             value = '[name="%s"]' % value
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#    1240             'value': value})['value']
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="location-typeahead-home-item-0"]"}
#   (Session info: chrome=96.0.4664.55)
# Stacktrace:
# 0   chromedriver                        0x000000010747a269 __gxx_personality_v0 + 582729
# 1   chromedriver                        0x0000000107405c33 __gxx_personality_v0 + 106003
# 2   chromedriver                        0x0000000106fc2e28 chromedriver + 171560
# 3   chromedriver                        0x0000000106ff83d2 chromedriver + 390098
# 4   chromedriver                        0x0000000106ff8591 chromedriver + 390545
# 5   chromedriver                        0x000000010702a6b4 chromedriver + 595636
# 6   chromedriver                        0x00000001070159fd chromedriver + 510461
# 7   chromedriver                        0x0000000107028462 chromedriver + 586850
# 8   chromedriver                        0x0000000107015c23 chromedriver + 511011
# 9   chromedriver                        0x0000000106feb75e chromedriver + 337758
# 10  chromedriver                        0x0000000106feca95 chromedriver + 342677
# 11  chromedriver                        0x00000001074368ab __gxx_personality_v0 + 305803
# 12  chromedriver                        0x000000010744d863 __gxx_personality_v0 + 399939
# 13  chromedriver                        0x0000000107452c7f __gxx_personality_v0 + 421471
# 14  chromedriver                        0x000000010744ebba __gxx_personality_v0 + 404890
# 15  chromedriver                        0x000000010742ae51 __gxx_personality_v0 + 258097
# 16  chromedriver                        0x000000010746a158 __gxx_personality_v0 + 516920
# 17  chromedriver                        0x000000010746a2e1 __gxx_personality_v0 + 517313
# 18  chromedriver                        0x00000001074816f8 __gxx_personality_v0 + 612568
# 19  libsystem_pthread.dylib             0x00007fff2036d8fc _pthread_start + 224
# 20  libsystem_pthread.dylib             0x00007fff20369443 thread_start + 15

# %%
print(orde)

# %%
# AQUI INTENTO SACAR TODA LA CAJA Y APENDEARLO EN UN DICCIONARIO, CAOS!

driver = webdriver.Chrome(ChromeDriverManager().install())
todoguarro = []
   
#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(2)
print("Url - Okey")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(2)
print("Cookies - Okey")
    
#LE DAMOS UNA DIRECCIÓN DE ENTREGA, HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(2)
print("Click dirección - Okey")

#TENEMOS QUE ESCRIBIR LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Lopez de Hoyos, 13, Madrid")
driver.implicitly_wait(2)
print("Dirección - Okey")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(2)
print("Confirmamos dirección - Okey")

#LE DAMOS UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(2)
print("Click categoría - Okey")

#TENEMOS QUE ESCRIBIR LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(2)
print("Categoría - Okey")
print("Estamos cerca!! ")

#SACAMOS LA DATA DE CADA TABLA
for number in range (1,80):
    todoguarro.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]').text)
    driver.implicitly_wait(2)
print("Congratulations, tenemos todo guarro!")

driver.quit
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/juanvegapenichet/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# Url - Okey
# Cookies - Okey
# Click dirección - Okey
# Dirección - Okey
# Confirmamos dirección - Okey
# Click categoría - Okey
# Categoría - Okey
# Estamos cerca!!
# Congratulations, tenemos todo guarro!
# <bound method ChromiumDriver.quit of <selenium.webdriver.chrome.webdriver.WebDriver (session="94aa62cd2409395df01cfdab6a04d2cd")>>

# %%
print(todoguarro)
# Out:
# ['La Tagliatella - Madrid Juan Bravo\nUno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 35 opiniones.\n4.6\n • \nLos gastos de envío son de 1.40€.\nPrecio de 1.40€\n • \n30–40 min', 'TUTTO PASTA!\nValorado con 2.9 de 5 estrellas según 28 opiniones.\n2.9\nLos gastos de envío son de 2.50€.\nPrecio de 2.50€\n • \n40–60 min', 'La Cuchara\n • \nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n35–45 min', "Papa John's - Príncipe\nValorado con 4.5 de 5 estrellas según más de 200 opiniones.\n4.5\nLos gastos de envío son de 1.40€.\nPrecio de 1.40€\n • \n25–35 min", 'Badsha India Restaurant\nValorado con 4.4 de 5 estrellas según más de 200 opiniones.\n4.4\nLos gastos de envío son de 1.00€.\nPrecio de 1.00€\n • \n15–35 min', 'TeKeS\nUno de los restaurantes mejor valorados con 4.9 de 5 estrellas según 76 opiniones.\n4.9\nLos gastos de envío son de 2.40€.\nPrecio de 2.40€\n • \n45–55 min', 'Makan Saj Manoushe\nUno de los restaurantes mejor valorados con 4.9 de 5 estrellas según más de 200 opiniones.\n4.9\n • \nLos gastos de envío son de 1.40€.\nPrecio de 1.40€\n • \n25–35 min', 'Hi Wok\nValorado con 4.3 de 5 estrellas según 38 opiniones.\n4.3\nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n35–45 min', 'Arepa Mix\nValorado con 4.0 de 5 estrellas según 29 opiniones.\n4.0\n • \nLos gastos de envío son de 5.00€.\nPrecio de 5.00€\n • \n20–40 min', 'Flor de Primavera\nValorado con 4.3 de 5 estrellas según más de 200 opiniones.\n4.3\nLos gastos de envío son de 0.50€.\nPrecio de 0.50€\n • \n25–45 min', 'Pizzart Luchana\n • \nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n45–55 min', 'Taco Bell - Concha Espina\nValorado con 4.4 de 5 estrellas según más de 200 opiniones.\n4.4\nLos gastos de envío son de 2.40€.\nPrecio de 2.40€\n • \n35–45 min', 'MY Pasta Room\nUno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 60 opiniones.\n4.6\n • \nLos gastos de envío son de 2.40€.\nPrecio de 2.40€\n • \n45–55 min', 'Casa Tua Gourmet\nUno de los restaurantes mejor valorados con 4.8 de 5 estrellas según 13 opiniones.\n4.8\n • \nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n40–50 min', "Juanchi's Burgers - Peñalver\nValorado con 4.3 de 5 estrellas según 103 opiniones.\n4.3\nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n30–40 min", 'Pastamore\nUno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 101 opiniones.\n4.6\n • \nLos gastos de envío son de 2.40€.\nPrecio de 2.40€\n • \n30–40 min', 'Chinawokexpress\nValorado con 4.2 de 5 estrellas según más de 200 opiniones.\n4.2\n • \nLos gastos de envío son de 4.25€.\nPrecio de 4.25€\n • \n30–50 min', 'Dalù Burger\n • \nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n35–45 min', 'Arepish Azcona\nUno de los restaurantes mejor valorados con 4.6 de 5 estrellas según más de 200 opiniones.\n4.6\n • \nLos gastos de envío son de 2.40€.\nPrecio de 2.40€\n • \n25–35 min', 'La Mordida - Chueca\n • \nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n45–55 min', 'Pic & Nic- San Andrés\nValorado con 4.4 de 5 estrellas según más de 200 opiniones.\n4.4\nLos gastos de envío son de 2.40€.\nPrecio de 2.40€\n • \n40–50 min', 'Ala Sushi\nLos gastos de envío son de 2.40€.\nPrecio de 2.40€\n • \n40–50 min', 'Empanadas Malvón - Zurbano\nUno de los restaurantes mejor valorados con 5.0 de 5 estrellas según 28 opiniones.\n5.0\n • \nLos gastos de envío son de 1.40€.\nPrecio de 1.40€\n • \n30–40 min', 'Fast chicken chain\nUno de los restaurantes mejor valorados con 5.0 de 5 estrellas según 11 opiniones.\n5.0\n • \nLos gastos de envío son de 2.90€.\nPrecio de 2.90€\n • \n45–55 min', 'VIPS - Génova\nUno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 15 opiniones.\n4.6\n • \nLos gastos de envío son de 1.90€.\nPrecio de 1.90€\n • \n40–50 min', 'Little Caesars Pizza - Bravo Murillo 113\nUno de los restaurantes mejor valorados con 4.6 de 5 estrellas según más de 200 opiniones.\n4.6\nLos gastos de envío son de 2.40€.\nPreci ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(todoguarro)

# %%
a = df.iloc[0]

# %%
a[0]
# Out:
# 'La Tagliatella - Madrid Juan Bravo\nUno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 35 opiniones.\n4.6\n • \nLos gastos de envío son de 1.40€.\nPrecio de 1.40€\n • \n30–40 min'

# %%
re.split('\n|•', a[0])
# Out:
# ['La Tagliatella - Madrid Juan Bravo',
#  'Uno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 35 opiniones.',
#  '4.6',
#  ' ',
#  ' ',
#  'Los gastos de envío son de 1.40€.',
#  'Precio de 1.40€',
#  ' ',
#  ' ',
#  '30–40 min']

# %%
final = []
for i in range(48):
    cuasilimpio = re.split('\n|•',df.iloc[i][0])
    #print(cuasilimpio)
    final.append(list(filter(lambda x:(x!=" "),cuasilimpio)))

# %%
final = []
for i in range(48):
    dicc = {"Restaurantes": None,
        "Valorado": None,
        "Nota": None,
        "Gastos": None,
        "Delivery fee": None,
        "ETA": None}
    cuasilimpio = re.split('\n|•',df.iloc[i][0])
    #print(cuasilimpio)
    lista_para_dic = list(filter(lambda x:(x!=" "),cuasilimpio))
        #Actualizar values de las keys de dicc, usando las condiciones de nuestras columnas
    dicc["Restaurantes"]= lista_para_dicc[0]
    for i in lista_para_dicc:
        if i.startswith("Uno de los") or i.startswith("Valorado con"):
            dicc["Valorado"] = i 
        elif i.startswith("Los gastos de"):
            dicc["Gastos"] = i
        elif

# %%
dicc = {"Restaurantes": [],
        "Valorado": [],
        "Nota": [],
        "Gastos": [],
        "Delivery fee": [],
        "ETA": []}

dicc["Gastos"]="FUNCIONA"

# %%
print(dicc)
# Out:
# {'Restaurantes': [], 'Valorado': [], 'Nota': [], 'Gastos': 'FUNCIONA', 'Delivery fee': [], 'ETA': []}

# %%
for i in final:
    #print(len(i))
# Out:
#   File "/var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_86322/3616460105.py", line 2
#     #print(len(i))
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
df = pd.DataFrame(final)
df.columns = ["Restaurantes","Valorado","Nota","Gastos","Delivery_Fee","ETA"]
df
# Out:
#                                 Restaurantes  \
# 0         La Tagliatella - Madrid Juan Bravo
# 1                               TUTTO PASTA!
# 2                                 La Cuchara
# 3                     Papa John's - Príncipe
# 4                    Badsha India Restaurant
# 5                                      TeKeS
# 6                         Makan Saj Manoushe
# 7                                     Hi Wok
# 8                                  Arepa Mix
# 9                          Flor de Primavera
# 10                           Pizzart Luchana
# 11                 Taco Bell - Concha Espina
# 12                             MY Pasta Room
# 13                          Casa Tua Gourmet
# 14              Juanchi's Burgers - Peñalver
# 15                                 Pastamore
# 16                           Chinawokexpress
# 17                               Dalù Burger
# 18                            Arepish Azcona
# 19                       La Mordida - Chueca
# 20                     Pic & Nic- San Andrés
# 21                                 Ala Sushi
# 22                Empanadas Malvón - Zurbano
# 23                        Fast chicken chain
# 24                             VIPS - Génova
# 25  Little Caesars Pizza - Bravo Murillo 113
# 26                            Artisan Burger
# 27                                Cachaparte
# 28                                     Flame
# 29                                     MANKA
# 30          Home Burger Bar - Santa Engracia
# 31                     Yakitoro - Castellana
# 32              Aloha Poke - Maria de Molina
# 33                          Cerveceria Riaño
# 34                             Freedom Pizza
# 35                          Limbo Player Two
# 36                                100 % Sano
# 37              Urban Poke - Alberto Alcocer
# 38                         McDonald's (Goya)
# 39                            Burnout Burger
# 40                         La cabaña de cris
# 41                           Shawarma palace
# 42                                     Tosty
# 43                                     Graal
# 44                Restaurante Chino Diamante
# 45                        Toro Burger Lounge
# 46                       CHUCK CHUCK CHICKEN
# 47                  Popeyes - López de Hoyos
#
#                                              Valorado             Nota  \
# 0   Uno de los restaurantes mejor valorados con 4....              4.6
# 1   Valorado con 2.9 de 5 estrellas según 28 opini...              2.9
# 2                   Los gastos de envío son de 1.90€.  Precio de 1.90€
# 3   Valorado con 4.5 de 5 estrellas según más de 2...              4.5
# 4   Valorado con 4.4 de 5 estrellas según más de 2...              4.4
# 5   Uno de los restaurantes mejor valorados con 4....              4.9
# 6   Uno de los restaurantes mejor valorados con 4....              4.9
# 7   Valorado con 4.3 de 5 estrellas según 38 opini...              4.3
# 8   Valorado con 4.0 de 5 estrellas según 29 opini...              4.0
# 9   Valorado con 4.3 de 5 estrellas según más de 2...              4.3
# 10                  Los gastos de envío son de 1.90€.  Precio de 1.90€
# 11  Valorado con 4.4 de 5 estrellas según más de 2...              4.4
# 12  Uno de los restaurantes mejor valorados con 4....              4.6
# 13  Uno de los restaurantes mejor valorados con 4....              4.8
# 14  Valorado con 4.3 de 5 estrellas según 103 opin...              4.3
# 15  Uno de los restaurantes mejor valorados con 4....              4.6
# 16  Valorado con 4.2 de 5 estrellas según más de 2...              4.2
# 17                  Los gastos de envío son de 1.90€.  Precio de 1.90€
# 18  Uno de los restaurantes mejor valorados con 4....              4.6
# 19                  Los gastos de envío son de 1.90€.  Precio de 1.90€
# 20  Valorado con 4.4 de 5 estrellas según más de 2...              4.4
# 21                  Los gastos de envío son de 2.40€.  Precio de 2.40€
# 22  Uno de los restaurantes mejor valorados con 5....              5.0
# 23  Uno de los restaurantes mejor valorados con 5....              5.0
# 24  Uno de los restaurantes mejor valorados con 4....              4.6
# 25  Uno de los restaurantes mejor valorados con 4....              4.6
# 26                  Los gastos de envío son de 0.90€.  Precio de 0.90€
# 27  Valorado con 4.3 de 5 estrellas según 22 opini...              4.3
# 28                  Los gastos de envío son de 1.40€.  Precio de 1.40€
# 29  Uno de los restaurantes mejor valorados con 4....              4.9
# 30  Valorado con 4.1 de 5 estrellas según 174 opin...              4.1
# 31  Uno de los restaurantes mejor valorados con 4....              4.5
# 32  Valorado con 4.4 de 5 estrellas según 169 opin...              4.4
# 33                  Los gastos de envío son de 2.90€.  Precio de 2.90€
# 34  Uno de los restaurantes mejor valorados con 4....              4.5
# 35                  Los gastos de envío son de 2.40€.  Precio de 2.40€
# 36                  Los gastos de envío son de 2.40€.  Precio de 2.40€
# 37                  Los gastos de envío son de 2.90€.  Precio de 2.90€
# 38  Uno de los restaurantes mejor valorados con 4....              4.6
# 39                  Los gastos de envío son de 1.90€.  Precio de 1.90€
# 40                  Los gastos de envío son de 2.90€.  Precio de 2.90€
# 41  Valorado con 3.5 de 5 estrellas según 15 opini...              3.5
# 42                  Los gastos de envío son de 2.40€.  Precio de 2.40€
# 43                  Los gastos de envío son de 2.40€.  Precio de 2.40€
# 44  Valorado con 4.0 de 5 estrellas según 99 opini...              4.0
# 45  Valorado con 4.2 de 5 estrellas según 24 opini...              4.2
# 46                  Los gastos de envío son de 1.90€.  Precio de 1.90€
# 47  Valorado con 4.4 de 5 estrellas según más de 2...              4.4
#
#                                Gastos     Delivery_Fee        ETA
# 0   Los gastos de envío son de 1.40€.  Precio de 1.40€  30–40 min
# 1   Los gastos de envío son de 2.50€.  Precio de 2.50€  40–60 min
# 2                           35–45 min             None       None
# 3   Los gastos de envío son de 1.40€.  Precio de 1.40€  25–35 min
# 4   Los gastos de envío son de 1.00€.  Precio de 1.00€  15–35 min
# 5   Los gastos de envío son de 2.40€.  Precio de 2.40€  45–55 min
# 6   Los gastos de envío son de 1.40€.  Precio de 1.40€  25–35 min
# 7   Los gastos de envío son de 1.90€.  Precio de 1.90€  35–45 min
# 8   Los gastos de envío son de 5.00€.  Precio de 5.00€  20–40 min
# 9   Los gastos de envío son de 0.50€.  Precio de 0.50€  25–45 min
# 10                          45–55 min             None       None
# 11  Los gastos de envío son de 2.40€.  Precio de 2.40€  35–45 min
# 12  Los gastos de envío son de 2.40€.  Precio de 2.40€  45–55 min
# 13  Los gastos de envío son de 1.90€.  Precio de 1.90€  40–50 min
# 14  Los gastos de envío son de 1.90€.  Precio de 1.90€  30–40 min
# 15  Los gastos de envío son de 2.40€.  Precio de 2.40€  30–40 min
# 16  Los gastos de envío son de 4.25€.  Precio de 4.25€  30–50 min
# 17                          35–45 min             None       None
# 18  Los gastos de envío son de 2.40€.  Precio de 2.40€  25–35 min
# 19                          45–55 min             None       None
# 20  Los gastos de envío son de 2.40€.  Precio de 2.40€  40–50 min
# 21                          40–50 min             None       None
# 22  Los gastos de envío son de 1.40€.  Precio de 1.40€  30–40 min
# 23  Los gastos de envío son de 2.90€.  Precio de 2.90€  45–55 min
# 24  Los gastos de envío son de 1.90€.  Precio de 1.90€  40–50 min
# 25  Los gastos de envío son de 2.40€.  Precio de 2.40€  40–50 min
# 26                          35–45 min             None       None
# 27  Los gastos de envío son de 1.90€.  Precio de 1.90€  35–45 min
# 28                          30–40 min             None       None
# 29  Los gastos de envío son de 2.90€.  Precio de 2.90€  45–55 min
# 30  Los gastos de envío son de 1.90€.  Precio de 1.90€  40–50 min
# 31  Los gastos de envío son de 1.90€.  Precio de 1.90€  50–60 min
# 32  Los gastos de envío son de 0.90€.  Precio de 0.90€  30–40 min
# 33                          40–50 min             None       None
# 34  Los gastos de envío son de 1.90€.  Precio de 1.90€  35–45 min
# 35                          45–55 min             None       None
# 36                          30–40 min             None       None
# 37                          35–45 min             None       None
# 38  Los gastos de envío son de 2.40€.  Precio de 2.40€  25–35 min
# 39                          40–50 min             None       None
# 40                          50–60 min             None       None
# 41  Los gastos de envío son de 2.40€.  Precio de 2.40€  45–55 min
# 42                          45–55 min             None       None
# 43                          45–55 min             None       None
# 44  Los gastos de envío son de 1.90€.  Precio de 1.90€  30–40 min
# 45  Los gastos de envío son de 2.40€.  Precio de 2.40€  50–60 min
# 46                          35–45 min             None       None
# 47  Los gastos de envío son de 2.40€.  Precio de 2.40€  35–45 min

# %%
# PATRONES DE UBER EATS

Nombre1 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[1]/div/div/div/div[2]/div[1]/div[1]
Nombre2 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[1]/div/div/div/div[2]/div[1]/div[1]
Nombre3 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[3]/div/div/div/div[2]/div[1]/div[1]
Nombre4 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[77]/div/div/div/div[2]/div[1]

NOMBRE1 = #main-content > div > div > div.b0.cd.ca.f3.e7.e8.e9.ea > div > div.kd.ke.kf.kg.kh.ki > div:nth-child(1) > div > div > div > div.ah.ai.f9 > div.l0.bx.ah.ec.c3 > div.ce.gz.cg.cu.bx.bb.b9.cs
NOMBRE2 = #main-content > div > div > div.b0.cd.ca.f3.e7.e8.e9.ea > div > div.kd.ke.kf.kg.kh.ki > div:nth-child(2) > div > div > div > div.ah.ai.f9 > div.l0.bx.ah.ec.c3 > div.ce.gz.cg.cu.bx.bb.b9.cs

Like & Nº 1 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[1]/div/div/div/div[2]/div[1]/span
Like & Nº 2 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[2]/div/div/div/div[2]/div[1]/img
Like & Nº 3 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[3]/div/div/div/div[2]/div[1]/span
Like & Nº 4 = 

LIKE1 = #main-content > div > div > div.b0.cd.ca.f3.e7.e8.e9.ea > div > div.kd.ke.kf.kg.kh.ki > div:nth-child(1) > div > div > div > div.ah.ai.f9 > div.l0.bx.ah.ec.c3 > div.ce.l1.cg.ch.ek.ej.l2.cj.ga.ah.c3.g9
LIKE2 = #main-content > div > div > div.b0.cd.ca.f3.e7.e8.e9.ea > div > div.kd.ke.kf.kg.kh.ki > div:nth-child(2) > div > div > div > div.ah.ai.f9 > div.l0.bx.ah.ec.c3 > img

Precio 1 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[1]/div/div/div/div[2]/div[2]/div[2]
Precio 2 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[2]/div/div/div/div[2]/div[2]/div[2]
Precio 3 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[3]/div/div/div/div[2]/div[2]/div[1]
Precio 4 = 

ETA 1 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[1]/div/div/div/div[2]/div[2]/div[3]/span/div
ETA 2 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[2]/div/div/div/div[2]/div[2]/div[3]
ETA 3 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[3]/div/div/div/div[2]/div[2]/div[2]
ETA 4 = 


eta1 = #main-content > div > div > div.b0.cd.ca.f3.e7.e8.e9.ea > div > div.kd.ke.kf.kg.kh.ki > div:nth-child(2) > div > div > div > div.ah.ai.f9 > div.bx.e2.ah.c3.l3 > div.bb.b9.cs

FULL PATH CAJA 1 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[10]/div/div/div/div[2]
FULL PATH CAJA 2 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[11]/div/div/div/div[2]
FULL PATH CAJA 3 = 
FULL PATH CAJ 81 = /html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[45]/div/div/div/div[2]

# %%
# AQUI INTENTO SACAR TODO Y APENDEARLO EN UN DICCIONARIO, DE FORMA ORDENADA!!!
# ESPERO QUE SALGA ASÍ :)


driver = webdriver.Chrome(ChromeDriverManager().install())
ordenado = {"restaurantes": [], "likes": [], "precio": [], "eta": []}
   
#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(2)
print("Url - Okey")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(2)
print("Cookies - Okey")
    
#LE DAMOS UNA DIRECCIÓN DE ENTREGA, HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(2)
print("Click dirección - Okey")

#TENEMOS QUE ESCRIBIR LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Lopez de Hoyos, 13, Madrid")
driver.implicitly_wait(2)
print("Dirección - Okey")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(2)
print("Confirmamos dirección - Okey")

#LE DAMOS UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(2)
print("Click categoría - Okey")

#TENEMOS QUE ESCRIBIR LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(2)
print("Categoría - Okey")
print("Estamos cerca!! ")

#SACAMOS LA DATA DE CADA TABLA
for number in range (1,80):
    try:
        ordenado["restaurantes"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/a/h3').text)
    except:
        ordenado["restaurantes"].append("NaN")
    try:
        ordenado["likes"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/span').text)
    except:
        ordenado["likes"].append("NaN")
    try:
        ordenado["precio"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[2]').text)
    except:
        ordenado["precio"].append("NaN")
    try:
        ordenado["eta"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[3]/span/div').text)
    except:
        ordenado["eta"].append("NaN")
        
    driver.implicitly_wait(2)
print("Congratulations, tenemos la data que necesitamos de la primera pagina!")

driver.quit
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/juanvegapenichet/.wdm/drivers/chromedriver/mac64/96.0.4664.45]
# Url - Okey
# Cookies - Okey
# Click dirección - Okey
# Dirección - Okey
# Confirmamos dirección - Okey
# Click categoría - Okey
# Categoría - Okey
# Estamos cerca!!
# Congratulations, tenemos la data que necesitamos de la primera pagina!
# <bound method ChromiumDriver.quit of <selenium.webdriver.chrome.webdriver.WebDriver (session="3104815a9f461a6285bd2bd67b958feb")>>

# %%
print(ordenado)
# Out:
# {'restaurantes': ["Papa John's - Príncipe", 'La Tagliatella - Madrid Orense', 'La Cuchara', 'Pizzart Luchana', 'Hi Wok', 'TeKeS', 'Taco Bell - Concha Espina', 'Casa Tua Gourmet', 'Chinawokexpress', 'Makan Saj Manoushe', 'Pizzería El Trébol 24h - Cuatro Caminos', 'Shawarma Station', 'El Burrito Borracho', 'Arepish Azcona', 'Lab84 Salamanca', 'Rawcoco', 'Pic & Nic- San Andrés', 'Arepish - Maravillas', 'Cachaparte', 'VIPS - Génova', 'Empanadas Malvón - Zurbano', 'Little Caesars Pizza - Bravo Murillo 113', "McDonald's (Goya)", 'La Craft Burger (Madrid - Gobernador)', 'Home Burger Bar - Santa Engracia', 'Pollos al Carbón EL MEJOR', 'Freedom Pizza', 'Shanghai Mama - Concha Espina', 'Artisan Burger', 'Aloha Poke - Maria de Molina', 'Flame', 'Nola Smoke - Madrid', 'Restaurante Chino Diamante', 'Yakitoro - Reina', 'Cor & Cor', 'Shawarma palace', 'CHUCK CHUCK CHICKEN', 'Restaurante Xuan', 'Popeyes - Cuatro Caminos', 'Pomodoro (Cuatro Caminos)', 'CarmenBar', 'Miss Poke - Hortaleza', 'Restaurante Mies', 'DITALY - Santa Engracia', 'Granjero Busca Campero', 'BRANDO', 'Tosty', 'Esmirna Doner Kebap', 'Tekkel Hot Dog', 'Tiendas 7x24 - Glorieta de Bilbao', 'Mad Pollo', 'Biba Chips', 'Napoli Gang by Bel Mondo - Salamanca', 'Tiendas 7x24 - Maldonado', 'Pizzart Fuencarral', 'Palacio de Oriente', 'Rodilla - María de Molina', 'That’s Amore', 'Doner Kebap Efes / Cartagena', 'Yokaloka', 'Baratie', 'Mahalo Poke Madrid', 'Las Muns Chueca', 'Frambons - Madrid', 'Golat Helados - Madrid', 'Labonata "la heladería de Chueca"', 'Empanadas BAIRES - Cuatro Caminos', 'Astros', 'Waiwai Fusion Poke Atocha', 'N2 Lab', 'Basically Just Burrito Bowls', 'CHOCOLATES VALOR - Madrid', 'Pizzamarket - Chamberí', 'MARKET CAFE Lequerica', 'MINIMARKET JMP ALIMENTACION', 'Sumo Grill', 'Steak Burger - Gran Via', 'Rude Burger', 'Goiko Basics'], 'likes': ['Valorado con 4.5 de 5 estrellas según más de 200 opiniones.', 'Valorado con 4.3 de 5 estrellas según 61 opiniones.', 'NaN', 'NaN', 'Valorado con 4.3 de 5 estrellas según 38 opiniones.', 'Uno de los restaurantes mejor valorados con 4.9 de 5 estrellas según 76 opiniones.', 'Valorado con 4.4 de 5 estrellas según más de 200 opiniones.', 'Uno de los restaurantes mejor valorados con 4.8 de 5 estrellas según 13 opiniones.', 'Valorado con 4.2 de 5 estrellas según más de 200 opiniones.', 'Uno de los restaurantes mejor valorados con 4.9 de 5 estrellas según más de 200 opiniones.', 'Valorado con 4.5 de 5 estrellas según 19 opiniones.', 'Valorado con 4.4 de 5 estrellas según 90 opiniones.', 'NaN', 'Uno de los restaurantes mejor valorados con 4.6 de 5 estrellas según más de 200 opiniones.', 'Uno de los restaurantes mejor valorados con 4.5 de 5 estrellas según 35 opiniones.', 'Uno de los restaurantes mejor valorados con 4.7 de 5 estrellas según más de 200 opiniones.', 'Valorado con 4.4 de 5 estrellas según más de 200 opiniones.', 'Uno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 61 opiniones.', 'Valorado con 4.3 de 5 estrellas según 22 opiniones.', 'Uno de los restaurantes mejor valorados con 4.6 de 5 estrellas según 15 opiniones.', 'Uno de los restaurantes mejor valorados con 5.0 de 5 estrellas según 28 opiniones.', 'Uno de los restaurantes mejor valorados con 4.6 de 5 estrellas según más de 200 opiniones.', 'Uno de los restaurantes mejor valorados con 4.6 de 5 estrellas según más de 200 opiniones.', 'Valorado con 4.4 de 5 estrellas según 67 opiniones.', 'Valorado con 4.1 de 5 estrellas según 179 opiniones.', 'Valorado con 3.5 de 5 estrellas según 20 opiniones.', 'Uno de los restaurantes mejor valorados con 4.5 de 5 estrellas según 52 opiniones.', 'Valorado con 4.2 de 5 estrellas según 18 opiniones.', 'NaN', 'Valorado con 4.4 de 5 estrellas según 169 opiniones.', 'NaN', 'Valorado con 4.2 de 5 estrellas según 184 opiniones.', 'Valorado con 4.0 de 5 estrellas según 99 opiniones.', 'Valorado con 3.9 de 5 estrellas según 28 opiniones.', 'Valorado con 4.4 de 5 estrellas según 38 opiniones.', 'Valorado con 3.5 de 5 estrellas se ...

# %%
df = pd.DataFrame(ordenado)

# %%
df.head(35)
# Out:
#                                 restaurantes  \
# 0                     Papa John's - Príncipe
# 1             La Tagliatella - Madrid Orense
# 2                                 La Cuchara
# 3                            Pizzart Luchana
# 4                                     Hi Wok
# 5                                      TeKeS
# 6                  Taco Bell - Concha Espina
# 7                           Casa Tua Gourmet
# 8                            Chinawokexpress
# 9                         Makan Saj Manoushe
# 10   Pizzería El Trébol 24h - Cuatro Caminos
# 11                          Shawarma Station
# 12                       El Burrito Borracho
# 13                            Arepish Azcona
# 14                           Lab84 Salamanca
# 15                                   Rawcoco
# 16                     Pic & Nic- San Andrés
# 17                      Arepish - Maravillas
# 18                                Cachaparte
# 19                             VIPS - Génova
# 20                Empanadas Malvón - Zurbano
# 21  Little Caesars Pizza - Bravo Murillo 113
# 22                         McDonald's (Goya)
# 23     La Craft Burger (Madrid - Gobernador)
# 24          Home Burger Bar - Santa Engracia
# 25                 Pollos al Carbón EL MEJOR
# 26                             Freedom Pizza
# 27             Shanghai Mama - Concha Espina
# 28                            Artisan Burger
# 29              Aloha Poke - Maria de Molina
# 30                                     Flame
# 31                       Nola Smoke - Madrid
# 32                Restaurante Chino Diamante
# 33                          Yakitoro - Reina
# 34                                 Cor & Cor
#
#                                                 likes  \
# 0   Valorado con 4.5 de 5 estrellas según más de 2...
# 1   Valorado con 4.3 de 5 estrellas según 61 opini...
# 2                                                 NaN
# 3                                                 NaN
# 4   Valorado con 4.3 de 5 estrellas según 38 opini...
# 5   Uno de los restaurantes mejor valorados con 4....
# 6   Valorado con 4.4 de 5 estrellas según más de 2...
# 7   Uno de los restaurantes mejor valorados con 4....
# 8   Valorado con 4.2 de 5 estrellas según más de 2...
# 9   Uno de los restaurantes mejor valorados con 4....
# 10  Valorado con 4.5 de 5 estrellas según 19 opini...
# 11  Valorado con 4.4 de 5 estrellas según 90 opini...
# 12                                                NaN
# 13  Uno de los restaurantes mejor valorados con 4....
# 14  Uno de los restaurantes mejor valorados con 4....
# 15  Uno de los restaurantes mejor valorados con 4....
# 16  Valorado con 4.4 de 5 estrellas según más de 2...
# 17  Uno de los restaurantes mejor valorados con 4....
# 18  Valorado con 4.3 de 5 estrellas según 22 opini...
# 19  Uno de los restaurantes mejor valorados con 4....
# 20  Uno de los restaurantes mejor valorados con 5....
# 21  Uno de los restaurantes mejor valorados con 4....
# 22  Uno de los restaurantes mejor valorados con 4....
# 23  Valorado con 4.4 de 5 estrellas según 67 opini...
# 24  Valorado con 4.1 de 5 estrellas según 179 opin...
# 25  Valorado con 3.5 de 5 estrellas según 20 opini...
# 26  Uno de los restaurantes mejor valorados con 4....
# 27  Valorado con 4.2 de 5 estrellas según 18 opini...
# 28                                                NaN
# 29  Valorado con 4.4 de 5 estrellas según 169 opin...
# 30                                                NaN
# 31  Valorado con 4.2 de 5 estrellas según 184 opin...
# 32  Valorado con 4.0 de 5 estrellas según 99 opini...
# 33  Valorado con 3.9 de 5 estrellas según 28 opini...
# 34  Valorado con 4.4 de 5 estrellas según 38 opini...
#
#                                                precio        eta
# 0                                           30–40 min        NaN
# 1                                           40–50 min        NaN
# 2   Los gastos de envío son de 1.90€.\nPrecio de 1...  35–45 min
# 3   Los gastos de envío son de 1.90€.\nPrecio de 1...  50–60 min
# 4                                           40–50 min        NaN
# 5                                           40–50 min        NaN
# 6                                           35–45 min        NaN
# 7   Los gastos de envío son de 1.90€.\nPrecio de 1...  40–50 min
# 8   Los gastos de envío son de 4.25€.\nPrecio de 4...  30–50 min
# 9   Los gastos de envío son de 1.40€.\nPrecio de 1...  25–35 min
# 10                                          45–55 min        NaN
# 11  Los gastos de envío son de 2.40€.\nPrecio de 2...  40–50 min
# 12                                          45–55 min        NaN
# 13  Los gastos de envío son de 2.40€.\nPrecio de 2...  30–40 min
# 14  Los gastos de envío son de 1.90€.\nPrecio de 1...  40–50 min
# 15  Los gastos de envío son de 1.90€.\nPrecio de 1...  35–45 min
# 16                                          40–50 min        NaN
# 17  Los gastos de envío son de 2.40€.\nPrecio de 2...  45–55 min
# 18  Los gastos de envío son de 1.90€.\nPrecio de 1...  40–50 min
# 19  Los gastos de envío son de 1.90€.\nPrecio de 1...  45–55 min
# 20  Los gastos de envío son de 1.40€.\nPrecio de 1...  30–40 min
# 21                                          45–55 min        NaN
# 22                                          20–30 min        NaN
# 23                                          15–35 min        NaN
# 24                                          40–50 min        NaN
# 25                                          15–35 min        NaN
# 26  Los gastos de envío son de 1.90€.\nPrecio de 1...  35–45 min
# 27                                          45–65 min        NaN
# 28  Los gastos de envío son de 0.90€.\nPrecio de 0...  40–50 min
# 29  Los gastos de envío son de 0.90€.\nPrecio de 0...  30–40 min
# 30  Los gastos de envío son de 1.40€.\nPrecio de 1...  35–45 min
# 31                                          45–55 min        NaN
# 32  Los gastos de envío son de 1.90€.\nPrecio de 1...  30–40 min
# 33  Los gastos de envío son de 2.40€.\nPrecio de 2...  55–65 min
# 34  Los gastos de envío son de 1.90€.\nPrecio de 1...  40–50 min
