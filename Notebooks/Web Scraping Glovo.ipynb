# %% [markdown]
# IMPORTAMOS LAS LIBRERÍAS

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager
import warnings
import re
warnings.filterwarnings("ignore")

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# VAMOS A SCRAPPEAR LA PÁGINA WEB DE GLOVO

# %% [markdown]
# OPCIONES DE SELENIUM PARA EVITAR QUE SEPAN QUE ERES UN BOT

# %%
#Opciones de Selenium para evitar que sepan que eres un robot
opciones= Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
#para ocultarme como robot, pero me sigue diciendo que hay un software automatico usando chrome
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--start-maximized') #empezar maximizado
opciones.add_argument('user.data-dir=selenium') #guarda las cookies
opciones.add_argument('drive/adblock.crx') #adblocker
#opciones.add_argument('--incognito')#incognito window

# %%
results_list = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

#VAMOS A LA URL
driver.get("https://glovoapp.com/es/es/madrid/")
driver.implicitly_wait(5)
print("Url - Centro")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#onetrust-accept-btn-handler").click()
driver.implicitly_wait(5)
print("Cookies - Centro")
    
#HACEMOS CLICK EN "DIRECCIÓN"
driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div/div/div/span/section/div[2]/div/div[2]/div/div[1]/div[2]/div/div[2]').click()
driver.implicitly_wait(5)
print("Click dirección - Centro")

#ESCRIBIMOS LA DIRECCIÓN
driver.find_element_by_xpath('/html/body/div[1]/div/div/div[2]/div/div/div/div/div/form/div[1]/div[1]/div[1]/div/div/div/div[1]/input').send_keys("Plaza Mayor, Madrid")
driver.implicitly_wait(5)
print("Escribimos dirección - Centro")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('/html/body/div[1]/div/div/div[2]/div/div/div/div/div/form/div[1]/div[1]/div[1]/div/div/div/div[2]/div[1]/div[1]/ul/li[1]').click()
driver.implicitly_wait(5)
print("Confirmamos dirección - Centro")

#HACEMOS CLICK PARA DAR UNA CATEGORÍA
driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div/div/div/span/section/div[2]/div/section/div/div[3]/a').click()
driver.implicitly_wait(5)
print("Click categoría - Centro")

for number in range (1,49):
        my_info = driver.find_element_by_xpath(f'/html/body/div[1]/div/div/div[1]/div/div/div/main/div[2]/div/div/div[{number}]')
        results_list.append(my_info.text)
        print("Tenemos la info barrio I")
        break
    
driver.quit
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/juanvegapenichet/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# Url - Centro
# Cookies - Centro
# Click dirección - Centro
# Escribimos dirección - Centro
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_48047/3028875606.py in <module>
#      22
#      23 #CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
# ---> 24 driver.find_element_by_xpath('/html/body/div[1]/div/div/div[2]/div/div/div/div/div/form/div[1]/div[1]/div[1]/div/div/div/div[2]/div[1]/div[1]/ul/li[1]').click()
#      25 driver.implicitly_wait(5)
#      26 print("Confirmamos dirección - Centro")
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self) -> None:
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     691             params = {}
#     692         params['id'] = self._id
# --> 693         return self._parent.execute(command, params)
#     694
#     695     def find_element(self, by=By.ID, value=None):
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=96.0.4664.93)
# Stacktrace:
# 0   chromedriver                        0x000000010b5b1269 __gxx_personality_v0 + 582729
# 1   chromedriver                        0x000000010b53cc33 __gxx_personality_v0 + 106003
# 2   chromedriver                        0x000000010b0f9e28 chromedriver + 171560
# 3   chromedriver                        0x000000010b0fcca1 chromedriver + 183457
# 4   chromedriver                        0x000000010b0fcac1 chromedriver + 182977
# 5   chromedriver                        0x000000010b0fcd5c chromedriver + 183644
# 6   chromedriver                        0x000000010b131340 chromedriver + 398144
# 7   chromedriver                        0x000000010b13028b chromedriver + 393867
# 8   chromedriver                        0x000000010b124659 chromedriver + 345689
# 9   chromedriver                        0x000000010b14c962 chromedriver + 510306
# 10  chromedriver                        0x000000010b123f45 chromedriver + 343877
# 11  chromedriver                        0x000000010b14cc7e chromedriver + 511102
# 12  chromedriver                        0x000000010b15f462 chromedriver + 586850
# 13  chromedriver                        0x000000010b14cc23 chromedriver + 511011
# 14  chromedriver                        0x000000010b12275e chromedriver + 337758
# 15  chromedriver                        0x000000010b123a95 chromedriver + 342677
# 16  chromedriver                        0x000000010b56d8ab __gxx_personality_v0 + 305803
# 17  chromedriver                        0x000000010b584863 __gxx_personality_v0 + 399939
# 18  chromedriver                        0x000000010b589c7f __gxx_personality_v0 + 421471
# 19  chromedriver                        0x000000010b585bba __gxx_personality_v0 + 404890
# 20  chromedriver                        0x000000010b561e51 __gxx_personality_v0 + 258097
# 21  chromedriver                        0x000000010b5a1158 __gxx_personality_v0 + 516920
# 22  chromedriver                        0x000000010b5a12e1 __gxx_personality_v0 + 517313
# 23  chromedriver                        0x000000010b5b86f8 __gxx_personality_v0 + 612568
# 24  libsystem_pthread.dylib             0x00007fff2036d8fc _pthread_start + 224
# 25  libsystem_pthread.dylib             0x00007fff20369443 thread_start + 15

# %%
# AQUI INTENTO SACAR TODO Y APENDEARLO EN LISTAS DE CATEGORÍAS, EL MÁS CAÓTICO!


driver = webdriver.Chrome(ChromeDriverManager().install())
restaurantes = []
likes = []
precio = []
eta = []
   
#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(2)
print("Url - Okey")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(2)
print("Cookies - Okey")
    
#LE DAMOS UNA DIRECCIÓN DE ENTREGA, HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(2)
print("Click dirección - Okey")

#TENEMOS QUE ESCRIBIR LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Lopez de Hoyos, 13, Madrid")
driver.implicitly_wait(2)
print("Dirección - Okey")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(2)
print("Confirmamos dirección - Okey")

#LE DAMOS UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(2)
print("Click categoría - Okey")

#TENEMOS QUE ESCRIBIR LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(2)
print("Categoría - Okey")
print("Estamos cerca!! ")

#SACAMOS LA DATA DE CADA TABLA
for number in range (1,27):
    restaurantes.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/a/h3').text)
    likes.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/span').text)
    precio.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[2]').text)
    eta.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[3]/span/div').text)
    driver.implicitly_wait(2)
print("Congratulations, tenemos la data que necesitamos de la primera pagina!")

driver.quit

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
todoguarro = []
links = []
barrio = []

#ITERAMOS POR EL DICCIONARIO DE CARA A 1.DARLE UNA DIRECCIÓN Y 2. AÑADIR LA COLUMNA AL DATAFRAME
for b in barrios:
    
    #VAMOS A LA URL
    driver.get("https://www.ubereats.com/es")
    driver.implicitly_wait(5)
    print(f"Url - {b}")

    #ACEPTAMOS LAS COOKIES
    driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
    driver.implicitly_wait(5)
    print(f"Cookies - {b}")
    
    #HACEMOS CLICK EN "CERCA DE MI"
    driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
    driver.implicitly_wait(5)
    print(f"Click dirección - {b}")

        #NUEVO LUGAR DONDE DAR LA DIRECCIÓN
        #driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/a[2]').click()
        #driver.implicitly_wait(5)

        #NUEVO LUGAR DONDE DAR LA DIRECCIÓN
        #driver.find_element_by_xpath('//*[@id="wrapper"]/div[4]/div/div/div[2]/div[3]/div/div[2]/div[1]/div[2]/a').click()
        #driver.implicitly_wait(5)

        #NUEVO LUGAR DONDE DAR LA DIRECCIÓN
        #driver.find_element_by_xpath('//*[@id="wrapper"]/div[4]/div/div/div[2]/div[3]/div/div[2]/div[1]/div[2]/a').click()
        #driver.implicitly_wait(5)

    #ESCRIBIMOS LA DIRECCIÓN
    driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys(barrios[b])
    driver.implicitly_wait(5)
    print(f"Dirección - {b}")
            
    #CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
    driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
    driver.implicitly_wait(5)
    print(f"Confirmamos dirección - {b}")

    #HACEMOS CLICK PARA DAR UNA CATEGORÍA
    driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
    driver.implicitly_wait(5)
    print(f"Click categoría - {b}")

    #ESCRIBIMOS LA CATEGORÍA
    driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
    driver.implicitly_wait(5)
    driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
    driver.implicitly_wait(5)
    print(f"Categoría - {b}")
    print(f"Estamos cerca - {b}")
    driver.implicitly_wait(5)

    #ITERAMOS 80 VECES
    for number in range (1,80):
        #SACAMOS LA DATA DE CADA TABLA
        todoguarro.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]').text)
        driver.implicitly_wait(5)
        print(f"Congratulations, tenemos todo guarro {b}")
        #AÑADIMOS EL BARRIO QUE HEMOS SACADO
        barrio.append(b)
        print(f"Tenemos {b}")
        #AÑADIMOS LOS LINKS EN LA LISTA DE CARA AL PRÓXIMO WEB SCRAPING
        links.append(driver.find_element_by_xpath(f"/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/a").get_attribute("href"))
        print(f"Tenemos link {b}")

        driver.quit

# %%
"""driver = webdriver.Chrome(ChromeDriverManager().install())

#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(5)
print("Url - Centro")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(5)
print("Cookies - Centro")
    
#HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(5)
print("Click dirección - Centro")

#ESCRIBIMOS LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Plaza Mayor, Madrid")
driver.implicitly_wait(5)
print("Dirección - Centro")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(5)
print("Confirmamos dirección - Centro")

#HACEMOS CLICK PARA DAR UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(5)
print("Click categoría - Centro")

#ESCRIBIMOS LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.implicitly_wait(5)
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(5)
print("Categoría - Centro")
print("Estamos cerca - Centro")
driver.implicitly_wait(5)

#ITERAMOS 80 VECES
for number in range (1,80):
    #SACAMOS LA DATA DE CADA TABLA
    todoguarro.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]').text)
    driver.implicitly_wait(5)
    print("Congratulations, tenemos todo guarro Centro")
    #AÑADIMOS EL BARRIO QUE HEMOS SACADO
    barrio.append("Centro")
    print("Tenemos Centro")
    #AÑADIMOS LOS LINKS EN LA LISTA DE CARA AL PRÓXIMO WEB SCRAPING
    links.append(driver.find_element_by_xpath(f"/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/a").get_attribute("href"))
    print("Tenemos link Centro")


#ITERAMOS POR EL DICCIONARIO DE CARA A 1.DARLE UNA DIRECCIÓN Y 2. AÑADIR LA COLUMNA AL DATAFRAME
for b in barrios:

    #NUEVO LUGAR DONDE DAR LA DIRECCIÓN
    driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/a[2]').click()
    driver.implicitly_wait(5)

    #NUEVO LUGAR DONDE DAR LA DIRECCIÓN
    driver.find_element_by_xpath('//*[@id="wrapper"]/div[4]/div/div/div[2]/div[3]/div/div[2]/div[1]/div[2]/a').click()
    driver.implicitly_wait(5)

    #NUEVO LUGAR DONDE DAR LA DIRECCIÓN
    driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[4]/div/div/div[2]/div[3]/div/div[1]/input').click()
    driver.implicitly_wait(5)

    #ESCRIBIMOS LA DIRECCIÓN
    driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[4]/div/div/div[2]/div[3]/div/div[1]/input').send_keys(barrios[b])
    driver.implicitly_wait(5)
    print(f"Dirección - {b}")
            
    #CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
    driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/div[4]/div/div/div[2]/div[3]/div/ul/li[1]').click()
    driver.implicitly_wait(5)
    print(f"Confirmamos dirección - {b}")

    #ITERAMOS 80 VECES
    for number in range (1,80):
        try:
            #SACAMOS LA DATA DE CADA TABLA
            todoguarro.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]').text)
            driver.implicitly_wait(5)
            print(f"Congratulations, tenemos todo guarro {b}")
            
        except:
            try:
                #SACAMOS LA DATA DE CADA TABLA
                todoguarro.append(driver.find_element_by_xpath(f'//*[@id="main-content"]/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]').text)
                driver.implicitly_wait(5)
                print(f"Congratulations, tenemos todo guarro {b}")
            
            except:
                #SACAMOS LA DATA DE CADA TABLA
                todoguarro.append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]').text)
                driver.implicitly_wait(5)
                print(f"Congratulations, tenemos todo guarro {b}")
            
        #AÑADIMOS EL BARRIO QUE HEMOS SACADO
        barrio.append(b)
        print(f"Tenemos {b}")
        #AÑADIMOS LOS LINKS EN LA LISTA DE CARA AL PRÓXIMO WEB SCRAPING
        links.append(driver.find_element_by_xpath(f"/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/a").get_attribute("href"))
        print(f"Tenemos link {b}")

        driver.quit"""

# %%
# AQUI INTENTO SACAR TODO Y APENDEARLO EN UN DICCIONARIO, DE FORMA ORDENADA!!!
# ESPERO QUE SALGA ASÍ :)


driver = webdriver.Chrome(ChromeDriverManager().install())
dicc = {"Restaurantes": [],
        "Valorado": [],
        "Nota": [],
        "Gastos": [],
        "Delivery fee": [],
        "ETA": [],
        "Mierda1": [],
        "Mierda2": [],
        "Mierda3": []}
   
#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(2)
print("Url - Okey")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(2)
print("Cookies - Okey")
    
#LE DAMOS UNA DIRECCIÓN DE ENTREGA, HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(2)
print("Click dirección - Okey")

#TENEMOS QUE ESCRIBIR LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Lopez de Hoyos, 13, Madrid")
driver.implicitly_wait(2)
print("Dirección - Okey")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(2)
print("Confirmamos dirección - Okey")

#LE DAMOS UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(2)
print("Click categoría - Okey")

#TENEMOS QUE ESCRIBIR LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(2)
print("Categoría - Okey")
print("Estamos cerca!! ")

#SACAMOS LA DATA DE CADA TABLA
for number in range (1,80):
    try:
        dicc["Restaurantes"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/div[1]').text)
    except:
        dicc["Restaurantes"].append(driver.find_element_by_xpath(f'//*[@id="main-content"]/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/div[1]').text)
    try:
        dicc["Valorado"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.mg.dh.ah.b6.bf > span').text)
    except:
        dicc["Valorado"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/span').text)
    try:
        dicc["Nota"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.mg.dh.ah.b6.bf > div.ba.mh.bb.bu.fn.fm.mi.c6.he.ah.bf.bg').text)
    except:
        dicc["Nota"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/div[3]').text)
    try:
        dicc["Gastos"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]').text)
    except:
        dicc["Gastos"].append(driver.find_element_by_xpath(f'//*[@id="main-content"]/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]').text)
    try:
        dicc["Delivery_fee"].append(driver.find_element_by_xpath(f'//*[@id="main-content"]/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]/span[1]').text)
    except:
        dicc["Delivery_fee"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[{number}]/span[1]').text)
    try:
        dicc["ETA"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.dh.eu.ah.bf.en > div.ch.cf.hg').text)
    except:
        dicc["ETA"].append(driver.find_element_by_css_selector(f'#main-content > div > div > div.b0.dg.bz.i2.ez.f0.br.f1 > div > div.gv.lw.lx.h0.h1.ly > div:nth-child({number}) > div > div > div > div.ah.ai.g0 > div.dh.eu.ah.bf.en > div.ch.cf.hg > span > div').text)
    try:
        dicc["Mierda1"].append(driver.find_element_by_xpath(f'').text)
    except:
        dicc["Mierda1"].append
    try:
        dicc["Mierda2"].append(driver.find_element_by_xpath(f'').text)
    except:
        dicc["Mierda2"].append
    try:
        dicc["Mierda3"].append(driver.find_element_by_xpath(f'').text)
    except:
        dicc["Mierda3"].append

        driver.implicitly_wait(2)
        
print("Congratulations, tenemos la data que necesitamos de la primera pagina!")

driver.quit

# %%
# AQUI INTENTO SACAR TODO Y APENDEARLO EN UN DICCIONARIO, DE FORMA ORDENADA!!!
# ESPERO QUE SALGA ASÍ :)


driver = webdriver.Chrome(ChromeDriverManager().install())
ordenado = {"restaurantes": [], "likes": [], "precio": [], "eta": []}
   
#VAMOS A LA URL
driver.get("https://www.ubereats.com/es")
driver.implicitly_wait(2)
print("Url - Okey")

#ACEPTAMOS LAS COOKIES
driver.find_element_by_css_selector("#cookie-banner > div > div > div.ah.gf > button.bc.gg.gh.gk.bj.bk.bl.bm.bn.bo.bt.bu.ba.bb").click()
driver.implicitly_wait(2)
print("Cookies - Okey")
    
#LE DAMOS UNA DIRECCIÓN DE ENTREGA, HACEMOS CLICK EN "CERCA DE MI"
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').click()
driver.implicitly_wait(2)
print("Click dirección - Okey")

#TENEMOS QUE ESCRIBIR LA DIRECCIÓN
driver.find_element_by_xpath('//*[@id="location-typeahead-home-input"]').send_keys("Lopez de Hoyos, 13, Madrid")
driver.implicitly_wait(2)
print("Dirección - Okey")

#CONFIRMAMOS LA DIRECCIÓN RECONOCIDA
driver.find_element_by_xpath('//*[@id="location-typeahead-home-item-0"]').click()
driver.implicitly_wait(2)
print("Confirmamos dirección - Okey")

#LE DAMOS UNA CATEGORÍA
driver.find_element_by_xpath('//*[@id="wrapper"]/header/div/div/div[6]/div/div').click()
driver.implicitly_wait(2)
print("Click categoría - Okey")

#TENEMOS QUE ESCRIBIR LA CATEGORÍA
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys("Comida")
driver.find_element_by_xpath('//*[@id="search-suggestions-typeahead-input"]').send_keys(Keys.ENTER)
driver.implicitly_wait(2)
print("Categoría - Okey")
print("Estamos cerca!! ")

#SACAMOS LA DATA DE CADA TABLA
for number in range (1,80):
    try:
        ordenado["restaurantes"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/a/h3').text)
    except:
        ordenado["restaurantes"].append("NaN")
    try:
        ordenado["likes"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[1]/span').text)
    except:
        ordenado["likes"].append("NaN")
    try:
        ordenado["precio"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[2]').text)
    except:
        ordenado["precio"].append("NaN")
    try:
        ordenado["eta"].append(driver.find_element_by_xpath(f'/html/body/div[1]/div[1]/div/main/div/div/div[2]/div/div[2]/div[{number}]/div/div/div/div[2]/div[2]/div[3]/span/div').text)
    except:
        ordenado["eta"].append("NaN")
        
    driver.implicitly_wait(2)
print("Congratulations, tenemos la data que necesitamos de la primera pagina!")

driver.quit

# %%
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41538', '-3.70124']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41377', '-3.70737']}
{'type': 'Point', 'coordinates': ['40.43000', '-3.70099']}
{'type': 'Point', 'coordinates': ['40.40922', '-3.72105']}
{'type': 'Point', 'coordinates': ['40.41841', '-3.70073']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.39854', '-3.69618']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.42149', '-3.71954']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40781', '-3.70452']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41041', '-3.70607']}
{'type': 'Point', 'coordinates': ['40.41538', '-3.70124']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41799', '-3.70834']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41347', '-3.70389']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40597', '-3.70127']}
{'type': 'Point', 'coordinates': ['40.42557', '-3.70629']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.42146', '-3.70750']}
{'type': 'Point', 'coordinates': ['40.42541', '-3.71112']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40763', '-3.70495']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41156', '-3.71008']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41606', '-3.70853']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41775', '-3.71025']}
{'type': 'Point', 'coordinates': ['40.41122', '-3.70801']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.44112', '-3.71427']}
{'type': 'Point', 'coordinates': ['40.43905', '-3.70972']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40069', '-3.69925']}
{'type': 'Point', 'coordinates': ['40.39854', '-3.69618']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40163', '-3.70811']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41377', '-3.70737']}
{'type': 'Point', 'coordinates': ['40.40922', '-3.72105']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.39021', '-3.70016']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40391', '-3.70708']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.39215', '-3.72487']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.45069', '-3.67173']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41537', '-3.70106']}
{'type': 'Point', 'coordinates': ['40.41041', '-3.70607']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40763', '-3.70495']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.34096', '-3.69201']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41347', '-3.70389']}
{'type': 'Point', 'coordinates': ['40.41553', '-3.70175']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.38678', '-3.69811']}
{'type': 'Point', 'coordinates': ['40.41538', '-3.70124']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40547', '-3.70151']}
{'type': 'Point', 'coordinates': ['40.41053', '-3.69580']}
{'type': 'Point', 'coordinates': ['40.41107', '-3.70275']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41624', '-3.70883']}
{'type': 'Point', 'coordinates': ['40.41156', '-3.71008']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40302', '-3.69613']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.41013', '-3.69412']}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': None}
{'type': 'Point', 'coordinates': ['40.40069', '-3.69925']}
{'type': 'Point', 'coordinates': ['40.40861', '-3.69288']}
{'type': 'Point', 'coordinates': ['40.39854', '-3.69618']}
{'type': 'Point', 'coordinates': ['40.39879', '-3.69590']}
